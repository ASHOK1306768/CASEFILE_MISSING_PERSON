# %% [markdown]
# # Module 2: Data Preprocessing & Temporal Feature Extraction

# %%
import pandas as pd
import numpy as np
import sys
sys.path.append("../src")
from preprocessing import clean_gps_data

df_raw = pd.read_csv("../data/processed/indian_trajectories.csv")
print("Raw Records Count:", len(df_raw))

# Apply Data Cleaning & Feature Extraction (PDF Module 2)
df_clean = clean_gps_data(df_raw, filter_india_bounds=True)

print("Cleaned Records Count:", len(df_clean))
print("Extracted Temporal Features:")
print(df_clean[["Timestamp", "Hour", "Day", "Weekday", "Month", "Is_Weekend", "Is_Night"]].head(5))
