# %% [markdown]
# # Module 7 & 8: Markov Chain Route Prediction & Search Priority Scoring

# %%
import pandas as pd
import numpy as np
import joblib
import sys
sys.path.append("../src")
from search_priority import calculate_search_priority_score

df_cases = pd.read_csv("../data/synthetic/synthetic_case_data.csv")

# Compute Search Priority Score for Case 1
c1 = df_cases.iloc[0]
score, priority = calculate_search_priority_score(ml_prob=85.0, historical_freq=0.7, route_sim=0.8, distance_rel=0.75, time_rel=0.6, anomaly_evid=0.9)

print(f"Case ID: {c1['Case_ID']}")
print(f"Calculated Search Priority Score: {score:.2f} / 100")
print(f"Priority Level: {priority}")
