# %% [markdown]
# # Module 1: Data Collection & Dataset Overview
# CASEFILE: Indian Missing Person Investigation & Probable Location Prediction System

# %%
import pandas as pd
import numpy as np
import os
import sys

# Load Indian Datasets
traj_path = "../data/processed/indian_trajectories.csv"
case_path = "../data/synthetic/synthetic_case_data.csv"

df_traj = pd.read_csv(traj_path)
df_cases = pd.read_csv(case_path)

print("=== Indian GPS Trajectory Dataset ===")
print("Shape:", df_traj.shape)
print("Columns:", list(df_traj.columns))
print(df_traj.head(3))

print("\n=== Indian Missing Person Case Registry ===")
print("Shape:", df_cases.shape)
print("Columns:", list(df_cases.columns))
print(df_cases.head(3))
